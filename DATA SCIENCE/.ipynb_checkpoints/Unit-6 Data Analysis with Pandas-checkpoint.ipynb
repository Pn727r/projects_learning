# %% [markdown]
# Unit-6 Data Analysis with Pandas
#
# Instructor: Prof.Snehal Sathwara
#
# Class: 4CEIT

# %% [markdown]
# SignUp the www.kaggle.com and follow the below instructions.

# %% [markdown]
# Download the DataSet from the website and upload in the Drive.
#
# Reference: https://www.kaggle.com/shubh0799/churn-modelling

# %% [markdown]
# # **Mount The Drive as per the below command.**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Pandas**
# Pandas is fast, powerful, flexible and easy to use open source data analysis and manipulation tool.
#
# Pandas is a Python library.
#
# Pandas is used to analyze data.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Pandas Series**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Pandas DataFrames**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#pip install pandas # If you dont have pandas in your IDLE. install pandas by the given command

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/Data Set/Churn_Modelling.csv')
#df = pd.read_excel('xyz.xlsx', sheet_name = 'Page 1')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 0             1    15634602   Hargrave  ...               1       101348.88      1
# 1             2    15647311       Hill  ...               1       112542.58      0
# 2             3    15619304       Onio  ...               0       113931.57      1
# 3             4    15701354       Boni  ...               0        93826.63      0
# 4             5    15737888   Mitchell  ...               1        79084.10      0
# ...         ...         ...        ...  ...             ...             ...    ...
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [10000 rows x 14 columns]

# %%
df.head()  # First 5 rows will be printed as default
# Out:
#    RowNumber  CustomerId   Surname  ...  New Balance Random Column SqRoot_Balance
# 0          1    15634602  Hargrave  ...      1000.00      Good Day       0.000000
# 1          2    15647311      Hill  ...     84807.86      Good Day     289.495872
# 2          3    15619304      Onio  ...    160660.80      Good Day     399.575775
# 3          4    15701354      Boni  ...      1000.00      Good Day       0.000000
# 4          5    15737888  Mitchell  ...    126510.82      Good Day     354.275063
#
# [5 rows x 17 columns]

# %%
df.head(10)  # First 10 rows will be printed as manual
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
# 5          6    15574012       Chu  ...               0       149756.71      1
# 6          7    15592531  Bartlett  ...               1        10062.80      0
# 7          8    15656148    Obinna  ...               0       119346.88      1
# 8          9    15792365        He  ...               1        74940.50      0
# 9         10    15592389        H?  ...               1        71725.73      0
#
# [10 rows x 14 columns]

# %%
df.tail() # last 5 rows will be printed as default
# Out:
#       RowNumber  CustomerId    Surname  ...  IsActiveMember EstimatedSalary Exited
# 9995       9996    15606229   Obijiaku  ...               0        96270.64      0
# 9996       9997    15569892  Johnstone  ...               1       101699.77      0
# 9997       9998    15584532        Liu  ...               1        42085.58      1
# 9998       9999    15682355  Sabbatini  ...               0        92888.52      1
# 9999      10000    15628319     Walker  ...               0        38190.78      0
#
# [5 rows x 14 columns]

# %%
df.tail(10) # last 10 rows will be printed as default
# Out:
#       RowNumber  CustomerId  ... EstimatedSalary  Exited
# 9990       9991    15798964  ...        53667.08       0
# 9991       9992    15769959  ...        69384.71       1
# 9992       9993    15657105  ...       195192.40       0
# 9993       9994    15569266  ...        29179.52       0
# 9994       9995    15719294  ...       167773.55       0
# 9995       9996    15606229  ...        96270.64       0
# 9996       9997    15569892  ...       101699.77       0
# 9997       9998    15584532  ...        42085.58       1
# 9998       9999    15682355  ...        92888.52       1
# 9999      10000    15628319  ...        38190.78       0
#
# [10 rows x 14 columns]

# %%
df.info() # Entire info about the DataFrames
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Describe the statistical information of the numerical columns
df.describe()
# Out:
#          RowNumber    CustomerId  ...  EstimatedSalary        Exited
# count  10000.00000  1.000000e+04  ...     10000.000000  10000.000000
# mean    5000.50000  1.569094e+07  ...    100090.239881      0.203700
# std     2886.89568  7.193619e+04  ...     57510.492818      0.402769
# min        1.00000  1.556570e+07  ...        11.580000      0.000000
# 25%     2500.75000  1.562853e+07  ...     51002.110000      0.000000
# 50%     5000.50000  1.569074e+07  ...    100193.915000      0.000000
# 75%     7500.25000  1.575323e+07  ...    149388.247500      0.000000
# max    10000.00000  1.581569e+07  ...    199992.480000      1.000000
#
# [8 rows x 11 columns]

# %%
# Prints all the columns of the dataframe

df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'New Balance',
#        'Random Column', 'SqRoot_Balance'],
#       dtype='object')

# %%
# Transpose 

df.T
# Out:
#                      0         1         2     ...      9997       9998      9999
# RowNumber               1         2         3  ...      9998       9999     10000
# CustomerId       15634602  15647311  15619304  ...  15584532   15682355  15628319
# Surname          Hargrave      Hill      Onio  ...       Liu  Sabbatini    Walker
# CreditScore           619       608       502  ...       709        772       792
# Geography          France     Spain    France  ...    France    Germany    France
# Gender             Female    Female    Female  ...    Female       Male    Female
# Age                    42        41        42  ...        36         42        28
# Tenure                  2         1         8  ...         7          3         4
# Balance                 0   83807.9    159661  ...         0    75075.3    130143
# NumOfProducts           1         1         3  ...         1          2         1
# HasCrCard               1         0         1  ...         0          1         1
# IsActiveMember          1         1         0  ...         1          0         0
# EstimatedSalary    101349    112543    113932  ...   42085.6    92888.5   38190.8
# Exited                  1         0         1  ...         1          1         0
#
# [14 rows x 10000 columns]

# %%
#Sort your dataframe based on Age

df.sort_values('Age')
# Out:
#       RowNumber  CustomerId  ... EstimatedSalary  Exited
# 3512       3513    15657779  ...        86994.54       0
# 1678       1679    15569178  ...        71811.90       0
# 3517       3518    15757821  ...        41542.95       0
# 9520       9521    15673180  ...       126172.11       0
# 2021       2022    15795519  ...       197322.13       0
# ...         ...         ...  ...             ...     ...
# 3387       3388    15798024  ...       186235.98       0
# 3033       3034    15578006  ...       116537.96       0
# 2458       2459    15813303  ...        52952.24       0
# 6759       6760    15660878  ...        34436.83       0
# 6443       6444    15764927  ...       195563.99       0
#
# [10000 rows x 14 columns]

# %%
#Sort your dataframe based on Tenure

df.sort_values('Tenure')
# Out:
#       RowNumber  CustomerId  ... Random Column  SqRoot_Balance
# 5887       5888    15691287  ...      Good Day      376.584984
# 6709       6710    15587647  ...      Good Day      356.539787
# 6706       6707    15732235  ...      Good Day      314.401320
# 9205       9206    15758750  ...      Good Day      332.456268
# 9206       9207    15611767  ...      Good Day      365.682143
# ...         ...         ...  ...           ...             ...
# 621         622    15603134  ...      Good Day      409.729789
# 2007       2008    15727384  ...      Good Day      382.815595
# 245         246    15797219  ...      Good Day      351.422225
# 3419       3420    15684103  ...      Good Day        0.000000
# 4617       4618    15799932  ...      Good Day        0.000000
#
# [10000 rows x 17 columns]

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance  #Input Balance kind of string will not work here
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['New Balance'] = df['Balance'] + 1000
#df.head(5)
#df['Balance']
df['New Balance']
# Out:
# 0         1000.00
# 1        84807.86
# 2       160660.80
# 3         1000.00
# 4       126510.82
#           ...
# 9995      1000.00
# 9996     58369.61
# 9997      1000.00
# 9998     76075.31
# 9999    131142.79
# Name: New Balance, Length: 10000, dtype: float64

# %%
df['Random Column'] = 'Good Day'
#df.head(5)
df['Random Column']
# Out:
# 0       Good Day
# 1       Good Day
# 2       Good Day
# 3       Good Day
# 4       Good Day
#           ...
# 9995    Good Day
# 9996    Good Day
# 9997    Good Day
# 9998    Good Day
# 9999    Good Day
# Name: Random Column, Length: 10000, dtype: object

# %%
# How to access your rows

df[10:12]
# Out:
#    RowNumber  CustomerId   Surname  ...  Exited New Balance Random Column
# 0          1    15634602  Hargrave  ...       1     1000.00      Good Day
# 1          2    15647311      Hill  ...       0    84807.86      Good Day
#
# [2 rows x 16 columns]

# %%
df
# Out:
#       RowNumber  CustomerId  ... Random Column  SqRoot_Balance
# 0             1    15634602  ...      Good Day        0.000000
# 1             2    15647311  ...      Good Day      289.495872
# 2             3    15619304  ...      Good Day      399.575775
# 3             4    15701354  ...      Good Day        0.000000
# 4             5    15737888  ...      Good Day      354.275063
# ...         ...         ...  ...           ...             ...
# 9995       9996    15606229  ...      Good Day        0.000000
# 9996       9997    15569892  ...      Good Day      239.519540
# 9997       9998    15584532  ...      Good Day        0.000000
# 9998       9999    15682355  ...      Good Day      273.998741
# 9999      10000    15628319  ...      Good Day      360.753087
#
# [10000 rows x 17 columns]

# %% [markdown]
# ## **Conditional Statements**

# %%
new_df = df[df.Age > 50]

# %%
new_df
# Out:
#       RowNumber  CustomerId      Surname  ...  Exited New Balance Random Column
# 16           17    15737452        Romeo  ...       1   133602.88      Good Day
# 41           42    15738148       Clarke  ...       1   123522.32      Good Day
# 42           43    15687946      Osborne  ...       0   118419.35      Good Day
# 44           45    15684171      Bianchi  ...       0   156931.11      Good Day
# 58           59    15623944        T'ien  ...       1     1000.00      Good Day
# ...         ...         ...          ...  ...     ...         ...           ...
# 9936       9937    15653037        Parks  ...       0     1000.00      Good Day
# 9939       9940    15808971       Lajoie  ...       0     1000.00      Good Day
# 9948       9949    15735078    Onwughara  ...       0   140687.66      Good Day
# 9979       9980    15692664       Diribe  ...       0    91022.85      Good Day
# 9991       9992    15769959  Ajuluchukwu  ...       1    89381.21      Good Day
#
# [1261 rows x 16 columns]

# %%
len(df)
# Out:
# 10000

# %%
len(new_df)
# Out:
# 1261

# %%
new_df_Age_greater_50 = df[df.Age > 50]

# %%
new_df_Age_greater_50.head(5)
# Out:
#     RowNumber  CustomerId  Surname  ...  Exited New Balance Random Column
# 16         17    15737452    Romeo  ...       1   133602.88      Good Day
# 41         42    15738148   Clarke  ...       1   123522.32      Good Day
# 42         43    15687946  Osborne  ...       0   118419.35      Good Day
# 44         45    15684171  Bianchi  ...       0   156931.11      Good Day
# 58         59    15623944    T'ien  ...       1     1000.00      Good Day
#
# [5 rows x 16 columns]

# %% [markdown]
# ## **Treat Null Values: fillna/dropna**

# %%
df.Age.mean()
# Out:
# 38.9218

# %%
df['Age'].fillna(df.Age.mean())

# %%
df['Age'].fillna(10)
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
new_df.head(5)
# Out:
#     RowNumber  CustomerId  Surname  ...  Exited New Balance Random Column
# 16         17    15737452    Romeo  ...       1   133602.88      Good Day
# 41         42    15738148   Clarke  ...       1   123522.32      Good Day
# 42         43    15687946  Osborne  ...       0   118419.35      Good Day
# 44         45    15684171  Bianchi  ...       0   156931.11      Good Day
# 58         59    15623944    T'ien  ...       1     1000.00      Good Day
#
# [5 rows x 16 columns]

# %% [markdown]
# ## **Column Removal / Dropping**

# %%
new_df.pop('RowNumber') # Delete the RowNumber
# Out:
# 16        17
# 41        42
# 42        43
# 44        45
# 58        59
#         ...
# 9936    9937
# 9939    9940
# 9948    9949
# 9979    9980
# 9991    9992
# Name: RowNumber, Length: 1261, dtype: int64

# %% [markdown]
# new_df

# %%
new_df_Age_greater_50_1 = new_df_Age_greater_50.drop('RowNumber', axis=1) # Delete the RowNumber

# %%
new_df_Age_greater_50_1.head(5)
# Out:
#     CustomerId  Surname  CreditScore  ... Exited New Balance  Random Column
# 16    15737452    Romeo          653  ...      1   133602.88       Good Day
# 41    15738148   Clarke          465  ...      1   123522.32       Good Day
# 42    15687946  Osborne          556  ...      0   118419.35       Good Day
# 44    15684171  Bianchi          660  ...      0   156931.11       Good Day
# 58    15623944    T'ien          511  ...      1     1000.00       Good Day
#
# [5 rows x 15 columns]

# %%
new_df_Age_greater_50.head(5)
# Out:
#     RowNumber  CustomerId  Surname  ...  Exited New Balance Random Column
# 16         17    15737452    Romeo  ...       1   133602.88      Good Day
# 41         42    15738148   Clarke  ...       1   123522.32      Good Day
# 42         43    15687946  Osborne  ...       0   118419.35      Good Day
# 44         45    15684171  Bianchi  ...       0   156931.11      Good Day
# 58         59    15623944    T'ien  ...       1     1000.00      Good Day
#
# [5 rows x 16 columns]

# %% [markdown]
# ## **Apply Numpy Operation**

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Balance']
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['Balance'].apply(np.sqrt)
# Out:
# 0         0.000000
# 1       289.495872
# 2       399.575775
# 3         0.000000
# 4       354.275063
#            ...
# 9995      0.000000
# 9996    239.519540
# 9997      0.000000
# 9998    273.998741
# 9999    360.753087
# Name: Balance, Length: 10000, dtype: float64

# %%
df['SqRoot_Balance'] = df['Balance'].apply(np.sqrt) # Apply and to store in a new column

# %%
#Drops all the null values in Age column

df['Age'].dropna()
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
df.dropna()
# Out:
#       RowNumber  CustomerId  ... Random Column  SqRoot_Balance
# 0             1    15634602  ...      Good Day        0.000000
# 1             2    15647311  ...      Good Day      289.495872
# 2             3    15619304  ...      Good Day      399.575775
# 3             4    15701354  ...      Good Day        0.000000
# 4             5    15737888  ...      Good Day      354.275063
# ...         ...         ...  ...           ...             ...
# 9995       9996    15606229  ...      Good Day        0.000000
# 9996       9997    15569892  ...      Good Day      239.519540
# 9997       9998    15584532  ...      Good Day        0.000000
# 9998       9999    15682355  ...      Good Day      273.998741
# 9999      10000    15628319  ...      Good Day      360.753087
#
# [10000 rows x 17 columns]

# %% [markdown]
# # **Concat & Merging**

# %%
import pandas as pd

df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, 
                  index=[0,1,2,3])

# %%
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'], 
                    'B': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C4', 'C5', 'C6', 'C7'], 
                    'D': ['D4', 'D5', 'D6', 'D7']}, 
                  index=[4,5,6,7])

# %%
#frames = [df1,df2]

# %%
result = pd.concat([df1, df2])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
result
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'], 
                    'B': ['B0', 'B1', 'B2', 'B3'], 
                    'C': ['C0', 'C1', 'C2', 'C3'], 
                    'D': ['D0', 'D1', 'D2', 'D3']}, )


df2 = pd.DataFrame({'E': ['A4', 'A5', 'A6', 'A7'], 
                    'F': ['B4', 'B5', 'B6', 'B7'], 
                    'C': ['C0', 'C3', 'C6', 'C7'], 
                    'G': ['D4', 'D5', 'D6', 'D7']}, )


merge_df = pd.merge(df1, df2, on='C', how='outer')

# %%
merge_df
# Out:
#      A    B   C    D    E    F    G
# 0   A0   B0  C0   D0   A4   B4   D4
# 1   A1   B1  C1   D1  NaN  NaN  NaN
# 2   A2   B2  C2   D2  NaN  NaN  NaN
# 3   A3   B3  C3   D3   A5   B5   D5
# 4  NaN  NaN  C6  NaN   A6   B6   D6
# 5  NaN  NaN  C7  NaN   A7   B7   D7

# %% [markdown]
# # **loc vs iloc**

# %% [markdown]
# The main distinction between the two methods is:
#
# loc gets rows (and/or columns) with particular
# labels.
#
# iloc gets rows (and/or columns) at integer locations.

# %%
s = pd.Series(list("abcdef"), index=[49, 48, 47, 0, 1, 2]) 
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
s.loc[0]    # value at index label 0
# Out:
# 'd'

# %%
s.iloc[0]   # value at index location 0
# Out:
# 'a'

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)
# Out:
# 49    a
# dtype: object

# %% [markdown]
# # **What if you sort the Series**

# %%
s = s.sort_index()

# %%
s
# Out:
# 0     d
# 1     e
# 2     f
# 47    c
# 48    b
# 49    a
# dtype: object

# %%
s.iloc[0]
# Out:
# 'd'

# %%
s.loc[0]    # value at index label 0
# Out:
# 'd'

# %%
s.iloc[0]   # value at index location 0
# Out:
# 'd'

# %%
s.loc[0:1]  # rows at index labels between 0 and 1 (inclusive)
# Out:
# 0    d
# 1    e
# dtype: object

# %%
s.iloc[0:1] # rows at index location between 0 and 1 (exclusive)
# Out:
# 0    d
# dtype: object
